# %% [markdown]
# - Area calculation (Stokes Theorem)
# $$S=\iint dS=\oint y \,dx=-\oint x \,dy=\sum_i\int_0^1 x_i'(t)y_i(t) \,dt=-\sum_i\int_0^1 x_i(t)y_i'(t) \,dt$$
# $$\iint x\,dS=\oint xy \,dx=-\oint \frac{x^2}{2} \,dy$$
# - Intersection:
# $$\frac{x-x_0}{y-y_0}=\frac{x_1-x_0}{y_1-y_0}\Rightarrow[y(t)-y_0](x_1-x_2)-[x(t)-x_0](y_1-y_0)=0$$

# %%
# %reset
def X(t,X0,X1,X2,X3): return (1 - t)**3*X0 + 3*t*(1 - t)**2*X1 + 3*t**2*(1 - t)*X2 + t**3*X3
def Y(t,Y0,Y1,Y2,Y3): return (1 - t)**3*Y0 + 3*t*(1 - t)**2*Y1 + 3*t**2*(1 - t)*Y2 + t**3*Y3
def XDY(t,X0,Y0,X1,Y1,X2,Y2,X3,Y3): 
    return -3*(t*X0*(Y0 - Y1) + (1/2)*t**2*(3*X1*(Y0 - Y1) + X0*(-5*Y0 + 7*Y1 - 2*Y2))
                + (1/3)*t**3*(3*X2*(Y0 - Y1) - 6*X1*(2*Y0 - 3*Y1 + Y2) 
                + X0*(10*Y0 - 18*Y1 + 9*Y2 - Y3))
                + (1/6)*t**6*(-X0 + 3*X1 - 3*X2 + X3)*(Y0 - 3*Y1 + 3*Y2 - Y3) 
                + (1/5)*t**5*(9*X2*Y0 - 2*X3*Y0 - 21*X2*Y1 + 4*X3*Y1 + 15*X2*Y2 - 2*X3*Y2 
                + X0*(5*Y0 - 13*Y1 + 11*Y2 - 3*Y3) - 3*X2*Y3 + 6*X1*(-2*Y0 + 5*Y1 - 4*Y2 + Y3)) 
                + (1/4)*t**4*(-9*X2*Y0 + X3*Y0 + 15*X2*Y1 - X3*Y1 - 6*X2*Y2 
                + 3*X1*(6*Y0 - 12*Y1 + 7*Y2 - Y3) + X0*(-10*Y0 + 22*Y1 - 15*Y2 + 3*Y3)))
def YDX(t,X0,Y0,X1,Y1,X2,Y2,X3,Y3): 
    return -3*(t*(X0 - X1)*Y0 - (1/2)*t**2*(5*X0*Y0 - 7*X1*Y0 + 2*X2*Y0 - 3*X0*Y1 + 3*X1*Y1)
            + (1/3)*t**3*(10*X0*Y0 + 9*X2*Y0 - X3*Y0 - 6*X2*Y1 - 3*X1*(6*Y0 - 6*Y1 + Y2)
            + 3*X0*(-4*Y1 + Y2)) + (1/6)*t**6*(-X0 + 3*X1 - 3*X2 + X3)*(Y0 - 3*Y1 + 3*Y2 - Y3)
            - (1/4)*t**4*(3*(5*X2*Y0 - X3*Y0 - 7*X2*Y1 + X3*Y1 + 2*X2*Y2) 
            + X0*(10*Y0 - 18*Y1 + 9*Y2 - Y3) + X1*(-22*Y0 + 36*Y1 - 15*Y2 + Y3)) 
            + (1/5)*t**5*(11*X2*Y0 - 3*X3*Y0 - 24*X2*Y1 + 6*X3*Y1 + 15*X2*Y2 - 3*X3*Y2 
            + X0*(5*Y0 - 12*Y1 + 9*Y2 - 2*Y3) - 2*X2*Y3 + X1*(-13*Y0 + 30*Y1 - 21*Y2 + 4*Y3)))
def getCOEF(X0,Y0,X1,Y1,X2,Y2,X3,Y3,x0,y0,x1,y1):
    return [(-x0 + x1)*Y0 - X0*(-y0 + y1) + 3*X1*(-y0 + y1) - 3*X2*(-y0 + y1) 
            + X3*(-y0 + y1) + 3*(x0 - x1)*Y1 - 3*(x0 - x1)*Y2 + (x0 - x1)*Y3
            , 3*(x0 - x1)*Y0 + 3*X0*(-y0 + y1) - 6*X1*(-y0 + y1) + 3*X2*(-y0 + y1)
            - 6*(x0 - x1)*Y1 + 3*(x0 - x1)*Y2
            , -3*(x0 - x1)*Y0 - 3*X0*(-y0 + y1) + 3*X1*(-y0 + y1) + 3*(x0 - x1)*Y1
            ,(-(x0 - x1))*y0 + (x0 - x1)*Y0 - x0*(-y0 + y1) + X0*(-y0 + y1)
           ]
def XDYL(t,x0,y0,x1,y1): return (1/2)*t*((-2 + t)*x0 - t*x1)*(y0 - y1)
def YDXL(t,x0,y0,x1,y1): return (1/2)*t*(x0 - x1)*((-2 + t)*y0 - t*y1)
def XYDX(t,X0,Y0,X1,Y1,X2,Y2,X3,Y3):
    return -3*(t*X0*(X0 - X1)*Y0 - (1/2)*t**2*(3*X1**2*Y0 + X0**2*(8*Y0 - 3*Y1) 
        + X0*(-13*X1*Y0 + 2*X2*Y0 + 3*X1*Y1)) + (1/3)*t**3*(9*X1*(3*X1*Y0 - X2*Y0 - X1*Y1) 
        - X0*(X3*Y0 + 6*X2*(-3*Y0 + Y1) + 3*X1*(21*Y0 - 12*Y1 + Y2)) 
        + X0**2*(28*Y0 + 3*(-7*Y1 + Y2))) + (1/5)*t**5*(2*X1*X3*(11*Y0 - 6*Y1) 
        + X2*(33*X2*Y0 - 5*X3*Y0 - 18*X2*Y1) - 9*X1*X2*(20*Y0 + 3*(-6*Y1 + Y2)) 
        + X0*(X3*(-20*Y0 + 18*Y1 - 3*Y2) - 5*X1*(49*Y0 - 66*Y1 + 24*Y2 - 2*Y3) 
        + 2*X2*(65*Y0 - 75*Y1 + 21*Y2 - Y3)) + 5*X0**2*(14*Y0 - 21*Y1 + 9*Y2 - Y3)
        + 3*X1**2*(65*Y0 - 75*Y1 + 21*Y2 - Y3))
        + (1/9)*t**9*(X0 - 3*X1 + 3*X2 - X3)**2*(Y0 - 3*Y1 + 3*Y2 - Y3)
        - (1/8)*t**8*(X0 - 3*X1 + 3*X2 - X3)*(14*X2*Y0 - 3*X3*Y0 - 33*X2*Y1 
        + 6*X3*Y1 + 24*X2*Y2 - 3*X3*Y2 + X0*(8*Y0 - 21*Y1 + 18*Y2 - 5*Y3) - 5*X2*Y3
        + X1*(-19*Y0 + 48*Y1 - 39*Y2 + 10*Y3)) - (1/4)*t**4*(6*X2**2*Y0 + X1*(-63*X2*Y0 
        + 4*X3*Y0 + 27*X2*Y1) + 9*X1**2*(11*Y0 - 8*Y1 + Y2) + X0**2*(56*Y0 - 63*Y1 + 18*Y2 - Y3) 
        + X0*(-7*X3*Y0 + 3*X3*Y1 + 6*X2*(11*Y0 - 8*Y1 + Y2) + X1*(-161*Y0 + 153*Y1 - 33*Y2 + Y3))) 
        - (1/6)*t**6*(72*X2**2*Y0 - 21*X2*X3*Y0 + X3**2*Y0 - 81*X2**2*Y1 + 15*X2*X3*Y1 + 18*X2**2*Y2
        + 6*X1*X3*(8*Y0 - 9*Y1 + 2*Y2) + X0**2*(56*Y0 - 105*Y1 + 60*Y2 - 10*Y3) 
        - 9*X1*X2*(30*Y0 - 42*Y1 + 15*Y2 - Y3) + X0*(-3*X1*(77*Y0 - 135*Y1 + 70*Y2 - 10*Y3)
        + 6*X2*(25*Y0 - 40*Y1 + 18*Y2 - 2*Y3) + X3*(-30*Y0 + 42*Y1 - 15*Y2 + Y3))
        + 9*X1**2*(25*Y0 - 2*(20*Y1 - 9*Y2 + Y3))) + (1/7)*t**7*(3*X3**2*(Y0 - Y1) 
        - 3*X2*X3*(11*Y0 - 16*Y1 + 5*Y2) + X0**2*(28*Y0 - 63*Y1 + 45*Y2 - 10*Y3)
        + 9*X1**2*(17*Y0 - 35*Y1 + 22*Y2 - 4*Y3) - 9*X1*X2*(25*Y0 - 48*Y1 + 27*Y2 - 4*Y3) 
        + 3*X2**2*(26*Y0 - 45*Y1 + 21*Y2 - 2*Y3) + 2*X1*X3*(26*Y0 - 45*Y1 + 21*Y2 - 2*Y3) 
        + X0*(6*X2*(17*Y0 - 35*Y1 + 22*Y2 - 4*Y3) + X3*(-25*Y0 + 48*Y1 - 27*Y2 + 4*Y3) 
        + X1*(-133*Y0 + 288*Y1 - 195*Y2 + 40*Y3))))
def XYDXL(t,x0,y0,x1,y1): 
    return (1/6)*t*(-x0 + x1)*(6*x0*y0 + 2*t**2*(x0 - x1)*(y0 - y1) + 3*t*(x1*y0 + x0*(-2*y0 + y1)))
def SL(xx1,yy1,xx2,yy2,XX1,YY1,XX2,YY2):
    k=(-(XX1 - XX2))*(yy1 - yy2) + (xx1 - xx2)*(YY1 - YY2)
    if(k==0): return []
    else:
        return np.array([xx2*XX2*(yy1 - YY1) + xx1*XX2*(YY1 - yy2) 
                         + xx1*XX1*(yy2 - YY2) + XX1*xx2*(-yy1 + YY2)
                         ,
                        XX2*YY1*(yy1 - yy2) + xx1*YY1*yy2 - XX1*yy1*YY2 
                         - xx1*yy2*YY2 + XX1*yy2*YY2 + xx2*yy1*(-YY1 + YY2)
                        ])/k
def hXXDY(t,X0,Y0,X1,Y1,X2,Y2,X3,Y3):
    return (-(3/2))*(t*X0**2*(Y0 - Y1) - t**2*X0*(3*X1*(-Y0 + Y1) + X0*(4*Y0 - 5*Y1 + Y2)) 
            +(1/3)*t**3*(9*X1**2*(Y0 - Y1) + 6*X0*(X2*(Y0 - Y1) + X1*(-7*Y0 + 9*Y1 - 2*Y2))
             + X0**2*(28*Y0 - 42*Y1 + 15*Y2 - Y3)) + (1/9)*t**9*(X0 
            - 3*X1 + 3*X2 - X3)**2*(Y0 - 3*Y1 + 3*Y2 - Y3)
             -  (1/4)*t**8*(X0 - 3*X1 + 3*X2 - X3)*(6*X2*Y0 - X3*Y0 - 15*X2*Y1 + 2*X3*Y1 + 12*X2*Y2 - X3*Y2 
            + X0*(4*Y0 - 11*Y1 + 10*Y2 - 3*Y3) - 3*X1*(3*Y0 - 8*Y1 + 7*Y2 - 2*Y3) - 
                 3*X2*Y3) - (1/3)*t**6*(3*X2*X3*(-Y0 + Y1) + 9*X2**2*(2*Y0 - 3*Y1 + Y2) 
            + 6*X1*X3*(2*Y0 - 3*Y1 + Y2) + X0**2*(28*Y0 - 63*Y1 + 45*Y2 - 10*Y3) - 
                 15*X0*X1*(7*Y0 - 15*Y1 + 10*Y2 - 2*Y3) + 18*X1**2*(5*Y0 - 10*Y1 + 6*Y2 - Y3) 
            + 12*X0*X2*(5*Y0 - 10*Y1 + 6*Y2 - Y3) + 9*X1*X2*(-10*Y0 + 18*Y1 - 9*Y2 + Y3) + 
                 X0*X3*(-10*Y0 + 18*Y1 - 9*Y2 + Y3)) + (1/7)*t**7*(54*X2**2*Y0 - 18*X2*X3*Y0 
            + X3**2*Y0 - 108*X2**2*Y1 + 30*X2*X3*Y1 - X3**2*Y1 + 63*X2**2*Y2 - 12*X2*X3*Y2 - 
                 2*X0*(3*X1*(21*Y0 - 51*Y1 + 40*Y2 - 10*Y3) - 3*X2*(15*Y0 - 35*Y1 + 26*Y2 - 6*Y3) 
            + X3*(10*Y0 - 22*Y1 + 15*Y2 - 3*Y3)) + X0**2*(28*Y0 - 70*Y1 + 57*Y2 - 15*Y3) 
            + 9*X1**2*(15*Y0 - 35*Y1 + 26*Y2 - 6*Y3) - 9*X2**2*Y3 - 6*X1*(X2*(30*Y0 - 66*Y1 + 45*Y2 - 9*Y3) 
            + X3*(-6*Y0 + 12*Y1 - 7*Y2 + Y3))) - (1/2)*t**4*(9*X1*(X2*(-Y0 + Y1) + X1*(3*Y0 - 4*Y1 + Y2)) 
            + X0**2*(28*Y0 - 49*Y1 + 24*Y2 - 3*Y3) + X0*(X3*(-Y0 + Y1) + 6*X2*(3*Y0 - 4*Y1 + Y2) 
            + X1*(-63*Y0 + 99*Y1 - 39*Y2 + 3*Y3))) +  (1/5)*t**5*(9*X2**2*(Y0 - Y1) - 6*X1*(X3*(-Y0 + Y1) 
            + 3*X2*(5*Y0 - 7*Y1 + 2*Y2)) + 5*X0**2*(14*Y0 - 28*Y1 + 17*Y2 - 3*Y3) 
            + 9*X1**2*(15*Y0 - 25*Y1 + 11*Y2 - Y3) 
            - 2*X0*(X3*(5*Y0 - 7*Y1 + 2*Y2) + 15*X1*(7*Y0 - 13*Y1 + 7*Y2 - Y3) 
            + X2*(-45*Y0 + 75*Y1 - 33*Y2 + 3*Y3))))
def hXXDYL(t,x0,y0,x1,y1): 
    return (-(1/6))*t*(3*x0**2 - 3*t*x0**2 + t**2*x0**2 + 3*t*x0*x1 - 2*t**2*x0*x1 + t**2*x1**2)*(y0 - y1)

# %%
# Common Func    
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
import numpy as np
from scipy.optimize import fsolve, fmin
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def Strp2cod():
    global cod,cmd,typ,xmin,xmax,ymin,ymax
    cod=[]
    cmd=[]
    typ=[]
    codsts=0
    codtmp=0.0
    lth=len(strp)
    i_s=i_e=0
    while (i_e<lth):
        i_s=i_e
        while (strp[i_e]!=" " and strp[i_e]!="\n"):
            i_e+=1
        if(strp[i_s]=="m"): #move to
            codsts=3
            cmd=cmd+[Path.MOVETO]
        elif(strp[i_s]=="l"): #line to
            codsts=3
            cmd=cmd+[Path.LINETO]
        elif(strp[i_s]=="c"): #curve to
            codsts=3
            cmd=cmd+[Path.CURVE4, Path.CURVE4, Path.CURVE4]
        elif(codsts==0): #not pairing
            codtmp=float(strp[i_s:i_e])
            codsts=1
        elif(codsts==1): #pairing
            cod=cod+[np.array([codtmp,float(strp[i_s:i_e])])]
            codsts=0
        elif(codsts==3): #add type
            codsts=0
            typ=typ+[strp[i_s:i_e]]
        while (i_e<lth and (strp[i_e]==" " or strp[i_e]=="\n")):
            i_e+=1
    global codNL
    codNL=[]
    idm=[]
    for idx in range(len(cod)):
        if(cmd[idx]==Path.MOVETO):
            idm=idm+[idx]
    idm=idm+[len(cod)]
    idm.reverse()
    for idx in range(len(idm)-1):
        if(idm[idx]==idm[idx+1]-1 or
            (cod[idm[idx]-1][0]-cod[idm[idx+1]][0])**2+
            (cod[idm[idx]-1][1]-cod[idm[idx+1]][1])**2
             >3.0
          ):
            codNL=codNL+[cod[idm[idx+1]],cod[idm[idx]-1]]
            del cod[idm[idx+1]:idm[idx]]
            del cmd[idm[idx+1]:idm[idx]]
            del typ[idm[idx+1]:idm[idx]]
               
    xmin=10000
    xmax=-10000
    ymin=10000
    ymax=-10000
    for i_ in range(len(cmd)):
        if(cod[i_][0]<xmin):
            xmin=cod[i_][0]
        elif(cod[i_][0]>xmax):
            xmax=cod[i_][0]
        if(cod[i_][1]<ymin):
            ymin=cod[i_][1]
        elif(cod[i_][1]>ymax):
            ymax=cod[i_][1]
    return xmin
            
def PlotGlyph(grd):
    global cod
    path = Path(cod, cmd)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    patch = patches.PathPatch(path, facecolor='black', lw=2)
    ax.add_patch(patch)
    plt.ylim(ymin,ymax)
    plt.xlim(xmin,xmax)
    ax.set_aspect('equal')
    if(grd):
        ax.set_xticks(np.arange(np.round(xmin,decimals=-2),xmax,50), minor=True)
        ax.set_yticks(np.arange(np.round(ymin,decimals=-2),ymax,50), minor=True)
        ax.grid(which='both')
    plt.show()

def ReadGlyph(g_fname): #extract to strp
    global strp
    hfile = open(g_fname)
    lnstr=hfile.readline()
    #Move to SplineSet
    while (lnstr[:9]!="SplineSet"):
        lnstr=hfile.readline()
        if (lnstr[:5]=="Width"):
            gwd=float(lnstr[7:])
        elif(lnstr==""): return -10000
    lnstr=hfile.readline()
    strp=''
    while (lnstr[:12]!="EndSplineSet"):
        strp=strp+lnstr
        lnstr=hfile.readline()
    hfile.close()
    return gwd

# %%
import numpy as np
def FdInts(xx1,yy1,xx2,yy2):
    n=len(cod)
    itr=0
    rts=np.array([[0.0,0.0]])
    while(itr<n):
        if(cmd[itr]==Path.MOVETO):
            itr+=1;
        elif(cmd[itr]==Path.CURVE4):
            coeff=getCOEF(cod[itr-1][0],cod[itr-1][1],
                     cod[itr][0],cod[itr][1],
                     cod[itr+1][0],cod[itr+1][1],
                     cod[itr+2][0],cod[itr+2][1],xx1,yy1,xx2,yy2)
            root=np.roots(coeff)
            root=np.real(root[np.isreal(root)])
            root=root[(root>0)&(root<1)]
            for rooti in root:
                rts=np.concatenate((rts,[[
                X(rooti,cod[itr-1][0],cod[itr][0],cod[itr+1][0],cod[itr+2][0]),
                Y(rooti,cod[itr-1][1],cod[itr][1],cod[itr+1][1],cod[itr+2][1])
                ]]))
            itr+=3
        elif(cmd[itr]==Path.LINETO):
            root=SL(xx1,yy1,xx2,yy2,cod[itr-1][0],cod[itr-1][1],
                     cod[itr][0],cod[itr][1])
            if(len(root)!=0 and
               ((root[1]-cod[itr-1][1])*(root[1]-cod[itr][1])<0 
                or (root[0]-cod[itr-1][0])*(root[0]-cod[itr][0])<0)):
                rts=np.concatenate((rts,np.array([root])))
            itr+=1
    return rts[1:]

# %%
def AreaAbove(yminn):
    n=len(cod)
    itr=0
    ss=0
    while(itr<n):
        if(cmd[itr]==Path.MOVETO):
            itr+=1;
        elif(cmd[itr]==Path.CURVE4):
            # find root
            coeff=getCOEF(cod[itr-1][0],cod[itr-1][1],
                     cod[itr][0],cod[itr][1],
                     cod[itr+1][0],cod[itr+1][1],
                     cod[itr+2][0],cod[itr+2][1],0,yminn,1,yminn)
            root=np.roots(coeff)
            root=np.real(root[np.isreal(root)])
            root=np.concatenate(([0],np.sort(root[(root>0)&(root<1)]),[1]))
            
            npts=len(root)-1
            
            for ri in range(npts):
                if(Y((root[ri]+root[ri+1])/2,
                     cod[itr-1][1],cod[itr][1],cod[itr+1][1],cod[itr+2][1])>yminn):
                    ss+=(XDY(root[ri],cod[itr-1][0],cod[itr-1][1],
                     cod[itr][0],cod[itr][1],
                     cod[itr+1][0],cod[itr+1][1],
                     cod[itr+2][0],cod[itr+2][1])
                    -XDY(root[ri+1],cod[itr-1][0],cod[itr-1][1],
                     cod[itr][0],cod[itr][1],
                     cod[itr+1][0],cod[itr+1][1],
                     cod[itr+2][0],cod[itr+2][1])
                    )
            itr+=3
            
        elif(cmd[itr]==Path.LINETO):
            if(cod[itr-1][1]!=cod[itr][1]):
                root=np.array([(cod[itr-1][1]-yminn)/(cod[itr-1][1]-cod[itr][1])])
                root=np.concatenate(([0],np.sort(root[(root>0)&(root<1)]),[1]))
                
                npts=len(root)-1            
                for ri in range(npts):
                    if(cod[itr-1][1]+(root[ri]+root[ri+1])/2
                         *(cod[itr][1]-cod[itr-1][1])>yminn):
                        ss+=(XDYL(root[ri],cod[itr-1][0],cod[itr-1][1],
                                cod[itr][0],cod[itr][1])
                                -XDYL(root[ri+1],cod[itr-1][0],cod[itr-1][1],
                                 cod[itr][0],cod[itr][1])
                            )
            itr+=1
    return ss

def XdSAbove(yminn):
    n=len(cod)
    itr=0
    ss=0
    while(itr<n):
        if(cmd[itr]==Path.MOVETO):
            itr+=1;
        elif(cmd[itr]==Path.CURVE4):
            # find root
            coeff=getCOEF(cod[itr-1][0],cod[itr-1][1],
                     cod[itr][0],cod[itr][1],
                     cod[itr+1][0],cod[itr+1][1],
                     cod[itr+2][0],cod[itr+2][1],0,yminn,1,yminn)
            root=np.roots(coeff)
            root=np.real(root[np.isreal(root)])
            root=np.concatenate(([0],np.sort(root[(root>0)&(root<1)]),[1]))
            
            npts=len(root)-1
            
            for ri in range(npts):
                if(Y((root[ri]+root[ri+1])/2,
                     cod[itr-1][1],cod[itr][1],cod[itr+1][1],cod[itr+2][1])>yminn):
                    ss+=(hXXDY(root[ri],cod[itr-1][0],cod[itr-1][1],
                     cod[itr][0],cod[itr][1],
                     cod[itr+1][0],cod[itr+1][1],
                     cod[itr+2][0],cod[itr+2][1])
                    -hXXDY(root[ri+1],cod[itr-1][0],cod[itr-1][1],
                     cod[itr][0],cod[itr][1],
                     cod[itr+1][0],cod[itr+1][1],
                     cod[itr+2][0],cod[itr+2][1])
                    )
            itr+=3
            
        elif(cmd[itr]==Path.LINETO):
            if(cod[itr-1][1]!=cod[itr][1]):
                root=np.array([(cod[itr-1][1]-yminn)/(cod[itr-1][1]-cod[itr][1])])
                root=np.concatenate(([0],np.sort(root[(root>0)&(root<1)]),[1]))
                
                npts=len(root)-1            
                for ri in range(npts):
                    if(cod[itr-1][1]+(root[ri]+root[ri+1])/2
                         *(cod[itr][1]-cod[itr-1][1])>yminn):
                        ss+=(hXXDYL(root[ri],cod[itr-1][0],cod[itr-1][1],
                                cod[itr][0],cod[itr][1])
                                -hXXDYL(root[ri+1],cod[itr-1][0],cod[itr-1][1],
                                 cod[itr][0],cod[itr][1])
                            )
            itr+=1
    return ss

# %%
def sweep(sbx,spi):
    xx=xmax+1
    spib=sbxb=10001
    while(xx>xmin):
        rooot=np.sort(np.transpose(FdInts(xx,0.0,xx,10.0))[1])
        if(len(rooot)>0):
            if(spib>10000 and rooot[-1]>spi):
                spib=xx
            if(sbxb>10000 and rooot[0]<sbx):
                sbxb=xx
            if(spib<10000 and sbxb<10000):
                break
        xx-=1
#     print(sbxb,spib)
    return(sbxb,spib)

# %%
def TopAccH():
    yy=ymax-30.2341
    op=np.sort(np.transpose(FdInts(0,yy,1,yy))[0])
    if(len(op)>2 and op[-1]-op[0]>200):
        return (op[-1]+op[0])/2
    else:
        return XdSAbove(yy)/AreaAbove(yy)
def nearest(pts):
    dist=99999999.0
    mxl=len(cod)
    idx=0
    while(idx<mxl):
        if(cmd[idx]==Path.MOVETO or
           cmd[idx]==Path.LINETO):
            ndist=(cod[idx][0]-pts[0])**2+(cod[idx][1]-pts[1])**2
            if(ndist<dist):
                dist=ndist
                rst=cod[idx]
        if(cmd[idx]==Path.CURVE4):
            idx+=2
            ndist=(cod[idx][0]-pts[0])**2+(cod[idx][1]-pts[1])**2
            if(ndist<dist):
                dist=ndist
                rst=cod[idx]
        idx+=1
    return rst
    
    
def TopAccHHalfMan(itaslop):
    if(len(codNL)==0):
        return TopAccH()
    elif(len(codNL)!=2):
        print("Warning: Incorrect top accent construction info!")
        return 0
    
    rst=FdInts(codNL[0][0],codNL[0][1],codNL[1][0],codNL[1][1]) 
    ninter=0
    for idx in range(len(rst)):
        if(    (rst[idx][0]>codNL[0][0] and rst[idx][0]<codNL[1][0]) or
               (rst[idx][0]<codNL[0][0] and rst[idx][0]>codNL[1][0]) or
               (rst[idx][1]>codNL[0][1] and rst[idx][1]<codNL[1][1]) or
               (rst[idx][1]<codNL[0][1] and rst[idx][1]>codNL[1][1])
          ):
            ninter+=1   
    if(ninter==0):# No intersec: avg(nearest);
        return 0.5*(nearest(codNL[0])[0]+nearest(codNL[1])[0])
    if(abs(codNL[0][0]-codNL[1][0])>abs(codNL[0][1]-codNL[1][1])):# horizontal: avg(nearest_intersec)+italic
        ht=.001+.5*(codNL[0][1]+codNL[1][1])
        rst=FdInts(codNL[0][0],ht,codNL[1][0],ht) 
        dist1=99999999.0
        dist2=99999999.0
        for idx in range(len(rst)):
            if((rst[idx][0]>codNL[0][0] and rst[idx][0]<codNL[1][0]) or
               (rst[idx][0]<codNL[0][0] and rst[idx][0]>codNL[1][0])):
                ndist=(rst[idx][0]-codNL[0][0])**2+(rst[idx][1]-ht)**2
                if(ndist<dist1):
                    dist1=ndist
                    rst1=rst[idx]                    
                ndist=(rst[idx][0]-codNL[1][0])**2+(rst[idx][1]-ht)**2
                if(ndist<dist2):
                    dist2=ndist
                    rst2=rst[idx]
        return 0.5*(rst1[0]+rst2[0])+itaslop*(ymax-ht)
    else:#vertical: nearest(avg)
            return nearest(0.5*(codNL[0]+codNL[1]))[0]
    
    return 0

# %%
def limfunc(dx,lim):
    if(dx<dxm): return 4*lim*dx
    elif (dx<dxm2): return lim*(dx+3*dxm)
    else : return lim*(3*dxm+dxm2)
    
def Diffract(hilim,slope,rtr,rtl):
    lolim=-70.9
    diff_max=3
    dif_wt=.025
    pen_length=400
    cut_length=25
    msk=np.arange(max(ymin+1.0015230,lolim),min(ymax-1.0015230,hilim))
    zz=msk.copy()
    llth=len(msk)
#     slope=.32
    
    limX=np.zeros(llth)+xmax
    limM=np.zeros(llth)+xmin
    
    
    dval=np.zeros(llth)
    val=np.zeros(llth)+1.0
    
    xx_current=xmax+.9926
    rightBlim=10000.0
    nHoldr=-1
    for itr in range(pen_length):
        xx_current-=1
        rst=np.transpose(FdInts(xx_current,0,xx_current,100))[1]
        rst=np.sort(rst)  
        lresult=len(rst)
#         if(lresult>0):
#             print(xx_current, rst[-1])
#         else:
#             print(xx_current)
        if(lresult>0 and rst[-1]>lolim and rightBlim>9999):
            rightBlim=xx_current
#         blacklth=0
#         for idx in range((int)(lresult/2)):
#             blacklth+=((int)(rst[2*idx+1])-(int)(rst[2*idx]))
        if(lresult>3):  
            for idx in range(llth):
                dval[idx]=0
                for idx1 in range(diff_max):
                    if(idx-idx1>=0):
                        dval[idx]+=(val[idx-idx1]*(diff_max-idx1))
                    if(idx+idx1<llth):
                        dval[idx]+=(val[idx+idx1]*(diff_max-idx1))
            for idx in range(cut_length):
                dval[idx]=dval[-1-idx]=0
            val+=dif_wt*dval
        
            nHoldr=abs(nHoldr)
        else:
            if(nHoldr<0):
                nHoldr-=1
        
        for idx in range((int)(lresult/2)):
            for idxx in range((int)(rst[2*idx+1])-(int)(rst[2*idx])):
                gitemp=idxx+(int)(rst[2*idx]-zz[0])
                if(gitemp>=0 and gitemp<llth):
                    val[gitemp]=0  
        
        for idx in range(llth):
            if(val[idx]>1):
                val[idx]=1
        limX-=val

    xx_current=xmin-.9926
    val=np.zeros(llth)+1.0
    leftBlim=-10000.0
    nHoldl=-1
    for itr in range(pen_length):
        xx_current+=1
        rst=np.transpose(FdInts(xx_current,0,xx_current,100))[1]
        rst=np.sort(rst)  
        lresult=len(rst)
        if(lresult>0 and rst[-1]>lolim and rst[0]<hilim and leftBlim<-9999):
            leftBlim=xx_current
#         blacklth=0
#         for idx in range((int)(lresult/2)):
#             blacklth+=((int)(rst[2*idx+1])-(int)(rst[2*idx]))
        if(lresult>3):  
            for idx in range(llth):
                dval[idx]=0
                for idx1 in range(diff_max):
                    if(idx-idx1>=0):
                        dval[idx]+=(val[idx-idx1]*(diff_max-idx1))
                    if(idx+idx1<llth):
                        dval[idx]+=(val[idx+idx1]*(diff_max-idx1))
            for idx in range(cut_length):
                dval[idx]=dval[-1-idx]=0
            val+=dif_wt*dval
    
            nHoldl=abs(nHoldl)
        else:
            if(nHoldl<0):
                nHoldl-=1
            
        for idx in range((int)(lresult/2)):
            for idxx in range((int)(rst[2*idx+1])-(int)(rst[2*idx])):
                gitemp=idxx+(int)(rst[2*idx]-zz[0])
                if(gitemp>=0 and gitemp<llth):
                    val[gitemp]=0   

        for idx in range(llth):
            if(val[idx]>1):
                    val[idx]=1
        limM+=val
    
    
#     #add reverse
#     for idx in range(llth):
#         limX[idx]=max(limX[idx],limX[llth-1-idx])
#         limM[idx]=min(limM[idx],limM[llth-1-idx])
    
    
    limX2=limX.copy()
    limM2=limM.copy()
    
    
    for itrtiri in range(llth):
        for itrtirj in range(llth):
            klim=limfunc(abs(itrtiri-itrtirj),slope)
            limX[itrtiri]=max(limX[itrtiri],limX2[itrtirj]-klim)
            limM[itrtiri]=min(limM[itrtiri],limM2[itrtirj]+klim)
        
#     fig = plt.figure()
#     ax = fig.add_subplot(1, 1, 1)
#     ax.set_aspect('equal')
#     ax.plot(limX,zz,"-",
#            limX2,zz,"-",
#             limM,zz,"-",
#            limM2,zz,"-"
#            )
    
    corr0=-(zz[0]-zz[-1])*slope/2
    if(rightBlim>9999):
        rightBlim=max(limX2)
    if(leftBlim<-9999):
        leftBlim=min(limM2)      
#     print(rightBlim, xmax, max(limX2))
    tmpr=[corr0-(max(limX2)-np.average(limX))
          +(rightBlim-xmax)+(max(limX2)-rightBlim)*rtr#.5
          ,corr0+min(limM2)-np.average(limM)
          +(xmin-leftBlim)-(min(limM2)-leftBlim)*rtl#1.0
         ]
#     print(max(limX2),np.average(limX))
    return((np.sign(tmpr)*(1-np.exp(-np.abs(tmpr)/130))*130))

# %%
#Read Mathtable Const
hfile = open("../Garamond-Math.sfdir/font.props")
lnstr="begin"
while (lnstr!=""):
    lnstr=hfile.readline()
    if (lnstr[5:27]=="ScriptPercentScaleDown"):
        ScriptPercentScaleDown=int(lnstr[29:])
    elif (lnstr[5:33]=="ScriptScriptPercentScaleDown"):
        ScriptScriptPercentScaleDown=int(lnstr[35:])
    elif (lnstr[5:23]=="SubscriptShiftDown"):
        SubscriptShiftDown=int(lnstr[25:])
    elif (lnstr[5:20]=="SubscriptTopMax"):
        SubscriptTopMax=int(lnstr[22:])
    elif (lnstr[5:29]=="SubscriptBaselineDropMin"):
        SubscriptBaselineDropMin=int(lnstr[31:])
    elif (lnstr[5:24]=="SuperscriptShiftUp:"):
        SuperscriptShiftUp=int(lnstr[25:])
    elif (lnstr[5:25]=="SuperscriptBottomMin"):
        SuperscriptBottomMin=int(lnstr[27:])
    elif (lnstr[5:31]=="SuperscriptBaselineDropMax"):
        SuperscriptBaselineDropMax=int(lnstr[33:])
hfile.close()

print(ScriptPercentScaleDown,
      ScriptScriptPercentScaleDown,
      SubscriptShiftDown,
      SubscriptTopMax,
      SubscriptBaselineDropMin,
      SuperscriptShiftUp,
      SuperscriptBottomMin,
      SuperscriptBaselineDropMax
    )

# %%
def SchB(tgt,src):
    for idd in range(len(src)):
        if(src[idd]==tgt):
            return idd
    return -1
def SchBSnd(tgt,src):
    for idd in range(len(src)):
        if(src[idd][0]==tgt):
            return idd
    return -1

# %%
def TransGlyph(g_fname,Word=False): #extract to strp
    global strp, outStr,xmin,cod
    hfile = open(dirin+"/"+g_fname+".glyph")
    hfileout= open(dirout+"/"+g_fname+".glyph","w")
    lnstr=hfile.readline()
    #Move to SplineSet
    while (lnstr[:9]!="SplineSet"):
        lnstr=hfile.readline()
        if (lnstr[:5]=="Width"):
            gwd=float(lnstr[7:])
        elif(lnstr==""):
            hfile.seek(0)
            hfileout.write(hfile.read())
            hfileout.close()
            hfile.close()
            return -10000
        
    idw=SchBSnd(g_fname,wdAll)
    idi=SchBSnd(g_fname,itaCorr)
    ide=SchB(g_fname,ExtendedGlf.gext)
    idt=SchBSnd(g_fname,TopAccent.topacc)
    idid=SchBSnd(g_fname,glflist.glfdat)

    
    lnstr=hfile.readline()
    strp=''
    while (lnstr[:12]!="EndSplineSet"):
        strp=strp+lnstr
        lnstr=hfile.readline()
    strAfter="EndSplineSet\n"+hfile.read()
    
    Strp2cod()
    
    if(idw>-1):
        mvVec=np.array([wdAll[idw][1]-xmin,0])
        for idz in range(len(cod)):
            cod[idz]=cod[idz]+mvVec
        gwd=wdAll[idw][1]-xmin+xmax+wdAll[idw][2]
#         print(wdAll[idw][1],wdAll[idw][2])
        xmin+=mvVec[0]
    if(idi>-1):
        icc=itaCorr[idi][1]
    else:
        icc=0
    
    hfile.seek(0)
    outStr=lnstr=hfile.readline()
    while (lnstr[:9]!="SplineSet"):
        lnstr=hfile.readline()
        if (lnstr[:5]=="Width"):
            if(idi>-1):
                if((Word and (ide<0)) or
                   ((not Word) and
                        ((idid>-1 and glflist.glfdat[idid][2]<.05) or
                         (idid<0 and ide<0)))): # word: non-exten ; TeX: upright
                    if(idw<0):
                        outStr+=lnstr
                    else:
                        outStr+=("Width: "+str(int(gwd))+ "\n")
                    outStr+=("BottomRightVertex: 1  0,"+str(-int(icc))+"\n")
                else:  
                    if(idw<0):
                        outStr+=lnstr
                    else:
                        outStr+=("Width: "+str(int(gwd-icc))+ "\n")
                    outStr+=("ItalicCorrection: "+str(int(icc))+ "\n")
            else:
                if(idw<0):
                    outStr+=lnstr
                else:
                    outStr+=("Width: "+str(int(gwd))+ "\n")
            if(idt>-1):
                outStr+=("TopAccentHorizontal: "+str(int(TopAccent.topacc[idt][1]+xmin))+ "\n")
            if(ide>-1):
                outStr+=("IsExtendedShape: 1\n")
        elif (lnstr[:19]!="TopAccentHorizontal" 
              and lnstr[:16]!="ItalicCorrection" 
              and lnstr[:17]!="BottomRightVertex" ):
            outStr+=lnstr
    
    idx=idy=0
    lth=len(cod)
    while(idx<lth):
        if(cmd[idx]!=Path.MOVETO):
            outStr+=" "
        outStr+=(str(int(cod[idx][0]))+" "+str(int(cod[idx][1]))+" ")
        if(cmd[idx]==Path.MOVETO):
            outStr+=("m "+ typ[idy]+"\n")
            idx+=1;
            idy+=1;
        elif(cmd[idx]==Path.LINETO):
            outStr+=("l "+ typ[idy]+"\n")
            idx+=1;
            idy+=1;
        else:
            idx+=1;
            outStr+=(str(int(cod[idx][0]))+" "+str(int(cod[idx][1]))+" ")
            idx+=1;
            outStr+=(str(int(cod[idx][0]))+" "+str(int(cod[idx][1]))+" ")
            outStr+=("c "+ typ[idy]+"\n")
            idx+=1;
            idy+=1;
    outStr+=strAfter
    hfileout.write(outStr)
    hfileout.close()
    hfile.close()
    return 1

def TransProps():
    hfile=open(dirin+"/font.props")
    stroutp=""
    if(not build4word):
        stroutp=hfile.read()
    else:
        lnstr=hfile.readline()
        while (lnstr!=""):
            if (lnstr[5:29]=="SubscriptBaselineDropMin"):
                SubscriptBaselineDropMin=int(lnstr[31:])
                stroutp+=("MATH:SubscriptBaselineDropMin: " 
                          + str(int(SubscriptBaselineDropMin/100.0*ScriptPercentScaleDown))+"\n")
            elif (lnstr[5:31]=="SuperscriptBaselineDropMax"):
                SuperscriptBaselineDropMax=int(lnstr[33:])
                stroutp+=("MATH:SuperscriptBaselineDropMax: " 
                          + str(int(SuperscriptBaselineDropMax/100.0*ScriptPercentScaleDown))+"\n")
            else:
                stroutp+=lnstr
            lnstr=hfile.readline()
#     print(stroutp)
    hfileo=open(dirout+"/font.props","w")
    hfileo.write(stroutp)
    hfileo.close()
    hfile.close()

# %%
build4word=False

import os
import widthKP
import width
import TopAccent
import ItalicCor
import ExtendedGlf
import ItalicCorExt
import widthdigits
import glflist

import importlib
importlib.reload(os)
importlib.reload(widthKP)
importlib.reload(width)
importlib.reload(TopAccent)
importlib.reload(ItalicCor)
importlib.reload(ExtendedGlf)
importlib.reload(ItalicCorExt)
importlib.reload(glflist)

itaCorr=ItalicCor.itaCor+ItalicCorExt.itaCorEx
wdAll=widthKP.wdkp+width.width+widthdigits.widthdigi

dirin="../Garamond-Math.sfdir"
if(not build4word):
    dirout="../../Release/Garamond-Math.sfdir"
else:
    dirout="../../Garamond-Math-Word.sfdir"

fnum=0
for path, subdirs, files in os.walk(dirin):
    for filename in files:
        if(filename[-1]!="h"):
            continue
        fnum+=1
print(fnum)
cnum=0
for path, subdirs, files in os.walk(dirin):
    for filename in files:
        if(filename[-1]!="h"):
            continue
        cnum+=1
        if((cnum % (int)(fnum/min(100,fnum)))==0): print("#",end="")
        if((cnum % (int)(fnum/5))==0): print("") 
        TransGlyph(filename[:-6],build4word)
TransProps()
print("Done!")

if(not build4word):
    # !build.bat
else:
    # !buildWord.bat

# %% [markdown]
# ### Below are codes for generating metrics

# %%
#width keep
import importlib
import glflist
importlib.reload(glflist)
import os

dirrr  ="../../gtemp/widthKeep.sfdir"
dirrref="../../gtemp/widthKeepSb.sfdir"

fnum=0
for path, subdirs, files in os.walk(dirrr):
    for filename in files:
        if(filename[-1]!="h"):
            continue
        fnum+=1
print(fnum)
cnum=0

hfileOUT=open("widthKP.py","w")
hfileOUT.write("wdkp=[\n")
for path, subdirs, files in os.walk(dirrr):
    for filename in files:
        if(filename[-1]!="h"):
            continue
        cnum+=1
        if((cnum % (int)(fnum/min(100,fnum)))==0): print("#",end="")
        if((cnum % (int)(fnum/5))==0): print("")    
        if(filename[-8:]==".s.glyph"):
            refxmax1=ReadGlyph(dirrr+"/"+filename[:-8]+".glyph")
            refxmin1=Strp2cod()
            refxmax1-=xmax
            refxmax2=ReadGlyph(dirrref+"/"+filename[:-8]+".glyph")
            refxmin2=Strp2cod()
            refxmax2-=xmax
            refxmax1=refxmax1*.8+refxmax2*.2
            refxmin1=refxmin1*.8+refxmin2*.2    
        elif(filename[-9:]==".ss.glyph"):
            refxmax1=ReadGlyph(dirrr+"/"+filename[:-9]+".glyph")
            refxmin1=Strp2cod()
            refxmax1-=xmax
            refxmax2=ReadGlyph(dirrref+"/"+filename[:-9]+".glyph")
            refxmin2=Strp2cod()
            refxmax2-=xmax
            refxmax1=refxmax1*.6+refxmax2*.4
            refxmin1=refxmin1*.6+refxmin2*.4    
        else:
            refxmax1=ReadGlyph(dirrr+"/"+filename)
            refxmin1=Strp2cod()
            refxmax1-=xmax
        hfileOUT.write("[\""+filename[:-6]+"\","+str(int(refxmin1))+","+str(int(refxmax1))+"],\n")
hfileOUT.write("]\n")
hfileOUT.close()
print("\nfinished")

# %%
#extended glyph

dirrr="../Garamond-Math.sfdir"
fnum=0
for path, subdirs, files in os.walk(dirrr):
    for filename in files:
        if(filename[-1]!="h"):
            continue
        fnum+=1
print(fnum)
cnum=0
hfileOUT=open("ExtendedGlf.py","w")
hfileOUT.write("gext=[\n")
for path, subdirs, files in os.walk(dirrr):
    for filename in files:
        if(filename[-1]!="h"):
            continue
        cnum+=1
        if((cnum % (int)(fnum/min(100,fnum)))==0): print("#",end="")
        if((cnum % (int)(fnum/5))==0): print("")   
        if(filename[-9:-6]==".dp"):
            hfileOUT.write("\""+filename[:-9]+"\",\n")   
            hfileOUT.write("\""+filename[:-6]+"\",\n")
        elif(filename[-9:-7]==".v" and ord(filename[-7])>=ord("1") and ord(filename[-7])<=ord("9")): 
            hfileOUT.write("\""+filename[:-6]+"\",\n")
        elif(filename[-10:-8]==".v" 
             and ord(filename[-8])>=ord("1") and ord(filename[-8])<=ord("9")
             and ord(filename[-7])>=ord("0") and ord(filename[-7])<=ord("9")): 
            hfileOUT.write("\""+filename[:-6]+"\",\n")    
hfileOUT.write("]\n")
hfileOUT.close()
print("\nfinished")

# %%
#Italic corr
import importlib
import glflist
import glfdigits

importlib.reload(glflist)
importlib.reload(glfdigits)
import os
glfdatAll=glflist.glfdat+glfdigits.glfdat

dirrr="../Garamond-Math.sfdir"
hfileOUT=open("ItalicCor.py","w")
hfileOUT.write("itaCor=[\n")

fnum=len(glfdatAll)
for idx in range(fnum):
#     if(glflist.glfdat[idx][2]<.05): continue;# no corr for upright.
    filename=dirrr+"/"+glfdatAll[idx][0]+".glyph"
    if((idx % (int)(fnum/min(100,fnum)))==0): print("#",end="")
    if((idx % (int)(fnum/5))==0): print("")  
    if(os.path.isfile(filename)):
        ReadGlyph(filename)
        Strp2cod()
        icc0=sweep(130,0)
        icc=max(0,icc0[1]-icc0[0])
        icc=(1-np.exp(-icc/200))*200
        if(icc>1.1):
            hfileOUT.write("[\""+glfdatAll[idx][0]+"\","+str(int(icc))+"],\n")     
hfileOUT.write("]\n")
hfileOUT.close()
print("\nfinished")

# %%
#Top Accent
import importlib
import glflist
import glfdigits

importlib.reload(glflist)
importlib.reload(glfdigits)
import os
glfdatAll=glflist.glfdat+glfdigits.glfdat

dirrr="../Garamond-Math.sfdir"
hfileOUT=open("TopAccent.py","w")
hfileOUT.write("topacc=[\n")

fnum=len(glfdatAll)
for idx in range(fnum):
    filename=dirrr+"/"+glfdatAll[idx][0]+".glyph"
    if((idx % (int)(fnum/min(100,fnum)))==0): print("#",end="")
    if((idx % (int)(fnum/5))==0): print("")  
    if(os.path.isfile(filename)):
        ReadGlyph(filename)
        Strp2cod()
#         print(filename)
        tpa=TopAccHHalfMan(glfdatAll[idx][2])
        if(int(tpa)!=0):
            hfileOUT.write("[\""+glfdatAll[idx][0]+"\","+str(int(tpa-xmin))+"],\n")     
hfileOUT.write("]\n")
hfileOUT.close()
print("\nfinished")

# %%
#Width
import importlib
import glflist
import widthKP
importlib.reload(widthKP)
importlib.reload(glflist)
import os

dirrr="../Garamond-Math.sfdir"
hfileOUT=open("width.py","w")
hfileOUT.write("width=[\n")
fnum=len(glflist.glfdat)
for idx in range(fnum):
    global hlim,dxm,dxm2
    if(SchBSnd(glflist.glfdat[idx][0],widthKP.wdkp)>-1): continue;# found.
    filename=dirrr+"/"+glflist.glfdat[idx][0]+".glyph"
    if((idx % (int)(fnum/min(100,fnum)))==0): print("#",end="")
    if((idx % (int)(fnum/5))==0): print("")  
    if(os.path.isfile(filename)):
        ReadGlyph(filename)
        Strp2cod()
#         print(idx)
        if(glflist.glfdat[idx][2]<.05):#upright
            if(glflist.glfdat[idx][1]<0):
                [hlim,dxm,dxm2]=[900,60,200]
            else:
                [hlim,dxm,dxm2]=[glflist.glfdat[idx][1],22,190]
            geocor=Diffract(hlim,.32,.5,1.0)
        else:
            if(glflist.glfdat[idx][1]<0):
                [hlim,dxm,dxm2]=[900,50,350]
            else:
                [hlim,dxm,dxm2]=[glflist.glfdat[idx][1],30,190]
            geocor=Diffract(hlim,.4,0.3,0.0)            
        hfileOUT.write("[\""+glflist.glfdat[idx][0]+"\","+str(int(geocor[1]))+","+str(int(geocor[0]))+"],\n")     
hfileOUT.write("]\n")
hfileOUT.close()
print("\nfinished")

# %%
#Width number
import importlib
import glfdigits
importlib.reload(glfdigits)
import os

dirrr="../Garamond-Math.sfdir"
hfileOUT=open("widthdigits.py","w")
hfileOUT.write("widthdigi=[\n")
fnum=len(glfdigits.glfdat)

for idx in range(fnum):
    global hlim,dxm,dxm2
    filename=dirrr+"/"+glfdigits.glfdat[idx][0]+".glyph"
    if((idx % (int)(fnum/min(100,fnum)))==0): print("#",end="")
    if((idx % (int)(fnum/5))==0): print("")  
    if(os.path.isfile(filename)):
        ReadGlyph(filename)
        Strp2cod()
        gwd=xmax-xmin
        [hlim,dxm,dxm2]=[900,60,200]
        geocor=Diffract(hlim,.32,.5,1.0) 
        gwd=0.5*(gwd+geocor[1]+geocor[0]-glfdigits.cwd)
        hfileOUT.write("[\""+glfdigits.glfdat[idx][0]+"\","+str(int(geocor[1]-gwd))+","+str(int(geocor[0]-gwd))+"],\n")     
hfileOUT.write("]\n")
hfileOUT.close()
print("\nfinished")

# %%
SchBSnd("Ifraktur",glflist.glfdat)
ReadGlyph("../AuroraMath.sfdir/Ifraktur.glyph")
Strp2cod()

# %%
#Width
import importlib
import glflist
import widthKP
importlib.reload(widthKP)
importlib.reload(glflist)
import os
glflist.glfdat=[["u1D453",450,1]]
dirrr="../Garamond-Math.sfdir"
fnum=len(glflist.glfdat)
for idx in range(fnum):
    global hlim,dxm,dxm2
    if(SchBSnd(glflist.glfdat[idx][0],widthKP.wdkp)>-1): continue;# found.
    filename=dirrr+"/"+glflist.glfdat[idx][0]+".glyph"
    print(filename)
    if(os.path.isfile(filename)):
        ReadGlyph(filename)
        Strp2cod()
#         print(idx)
        if(glflist.glfdat[idx][2]<.05):#upright
            if(glflist.glfdat[idx][1]<0):
                [hlim,dxm,dxm2]=[900,60,200]
            else:
                [hlim,dxm,dxm2]=[glflist.glfdat[idx][1],22,190]
            geocor=Diffract(hlim,.32,.5,1.0)
        else:
            if(glflist.glfdat[idx][1]<0):
                [hlim,dxm,dxm2]=[900,50,350]
            else:
                [hlim,dxm,dxm2]=[glflist.glfdat[idx][1],30,190]
            geocor=Diffract(hlim,.4,0.0,0.0) 
            print(geocor)
print("\nfinished")
